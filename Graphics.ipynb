# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
barWidth = 0.25
fig = plt.subplots(figsize =(12, 8))
 
# set height of bar
IT = [12, 30, 1, 8, 22]
ECE = [28, 6, 16, 5, 10]
CSE = [29, 3, 24, 25, 17]
 
# Set position of bar on X axis
br1 = np.arange(len(IT))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
 
# Make the plot
plt.bar(br1, IT, color ='r', width = barWidth,
        edgecolor ='grey', label ='IT')
plt.bar(br2, ECE, color ='g', width = barWidth,
        edgecolor ='grey', label ='ECE')
plt.bar(br3, CSE, color ='b', width = barWidth,
        edgecolor ='grey', label ='CSE')
 
# Adding Xticks
plt.xlabel('Branch', fontweight ='bold', fontsize = 15)
plt.ylabel('Students passed', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(IT))],
        ['2015', '2016', '2017', '2018', '2019'])
 
plt.legend()
plt.show()

# %%
print(br1)
print(br2)
print(br3)
# Out:
# [0 1 2 3 4]
# [0.25, 1.25, 2.25, 3.25, 4.25]
# [0.5, 1.5, 2.5, 3.5, 4.5]

# %%
#Accuracies

barWidth = 0.2
fig = plt.subplots(figsize =(12, 8))
 
# set height of bar
p_000 = [86.91, 86.72, 85.9, 81.21, 67.2]
p_025 = [85.13, 85.48, 84.95, 81.19, 65.95]
p_050 = [82.58, 82.79, 82.78, 78.39, 67.36]
p_075 = [82.58, 82.79, 82.78, 78.39, 67.36]
 
# Set position of bar on X axis
br1 = np.arange(len(IT))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]
print(br1)
print(br2)
print(br3)
print(br4)
# Make the plot
plt.bar(br1, p_000, color ='#599ad3', width = barWidth,
        edgecolor ='grey', label ='\u03B1 = 0.00')
plt.bar(br2, p_025, color ='#f9a65a', width = barWidth,
        edgecolor ='grey', label ='\u03B1 = 0.25')
plt.bar(br3, p_050, color ='#9e66ab', width = barWidth,
        edgecolor ='grey', label ='\u03B1 = 0.50')
plt.bar(br4, p_075, color ='#cd7058', width = barWidth,
        edgecolor ='grey', label ='\u03B1 = 0.75')
 
# Adding Xticks
plt.xlabel('n° of bits',fontsize = 12)
plt.ylabel('Accuracy (%)',fontsize = 12)
plt.xticks([r + barWidth*1.5 for r in range(len(IT))],
        ['32 bits', '16 bits', '8 bits', '4 bits', '3 bits'])

plt.title("Accuracies",fontweight ='bold', fontsize = 15)

y = np.random.randint(low=0, high=105, size=100)
plt.yticks(np.arange(0, max(y), 5))

plt.grid(axis='y')
plt.legend(prop={'size': 13})
plt.show()
# Out:
# [0 1 2 3 4]
# [0.2, 1.2, 2.2, 3.2, 4.2]
# [0.4, 1.4, 2.4000000000000004, 3.4000000000000004, 4.4]
# [0.6000000000000001, 1.5999999999999999, 2.6000000000000005, 3.6000000000000005, 4.6000000000000005]

# %%
#Size

barWidth = 0.2
fig = plt.subplots(figsize =(12, 8))
 
# set height of bar
p_000 = [76.84, 38.42, 19.21, 9.61, 7.2]
p_025 = [36.54, 18.63, 9.48, 4.74, 3.77]
p_050 = [31.45, 16.08, 7.98, 4.47, 3.64]
p_075 = [23.5, 12.24, 6.29, 3.38, 2.92]
 
# Set position of bar on X axis
br1 = np.arange(len(IT))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]
print(br1)
print(br2)
print(br3)
print(br4)
# Make the plot
plt.bar(br1, p_000, color ='#599ad3', width = barWidth,
        edgecolor ='grey', label ='\u03B1 = 0.00')
plt.bar(br2, p_025, color ='#f9a65a', width = barWidth,
        edgecolor ='grey', label ='\u03B1 = 0.25')
plt.bar(br3, p_050, color ='#9e66ab', width = barWidth,
        edgecolor ='grey', label ='\u03B1 = 0.50')
plt.bar(br4, p_075, color ='#cd7058', width = barWidth,
        edgecolor ='grey', label ='\u03B1 = 0.75')
 
# Adding Xticks
plt.xlabel('n° of bits',fontsize = 12)
plt.ylabel('Size (MB)',fontsize = 12)
plt.xticks([r + barWidth*1.5 for r in range(len(IT))],
        ['32 bits', '16 bits', '8 bits', '4 bits', '3 bits'])

plt.title("Model Size",fontweight ='bold', fontsize = 15)

y = np.random.randint(low=0, high=85, size=100)
plt.yticks(np.arange(0, max(y), 5))

plt.grid(axis='y')
plt.legend(prop={'size': 13})
plt.show()
# Out:
# [0 1 2 3 4]
# [0.2, 1.2, 2.2, 3.2, 4.2]
# [0.4, 1.4, 2.4000000000000004, 3.4000000000000004, 4.4]
# [0.6000000000000001, 1.5999999999999999, 2.6000000000000005, 3.6000000000000005, 4.6000000000000005]

# %%
#Size

barWidth = 0.2
fig = plt.subplots(figsize =(12, 8))
 
# set height of bar
#p_000 = [76.84, 38.42, 19.21, 9.61, 7.2]
p_025 = [52.45, 51.21, 50.65, 50.70, 47.72]
p_050 = [59.07, 58.15, 58.48, 53.49, 49.5]
p_075 = [69.43, 68.15, 67.28, 64.86, 59.42]
 
# Set position of bar on X axis
br1 = np.arange(len(IT))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
#br4 = [x + barWidth for x in br3]
print(br1)
print(br2)
print(br3)
#print(br4)
# Make the plot
plt.bar(br1, p_025, color ='#599ad3', width = barWidth,
        edgecolor ='grey', label ='\u03B1 = 0.25')
plt.bar(br2, p_050, color ='#f9a65a', width = barWidth,
        edgecolor ='grey', label ='\u03B1 = 0.50')
plt.bar(br3, p_075, color ='#9e66ab', width = barWidth,
        edgecolor ='grey', label ='\u03B1 = 0.75')
#plt.bar(br4, p_075, color ='#cd7058', width = barWidth,
#        edgecolor ='grey', label ='\u03B1 = 0.75')
 
# Adding Xticks
plt.xlabel('n° of bits',fontsize = 12)
plt.ylabel('Sparsity (%)',fontsize = 12)
plt.xticks([r + barWidth*1.5 for r in range(len(IT))],
        ['32 bits', '16 bits', '8 bits', '4 bits', '3 bits'])

plt.title("Model Sparsity",fontweight ='bold', fontsize = 15)

y = np.random.randint(low=0, high=85, size=100)
plt.yticks(np.arange(0, max(y), 5))

plt.grid(axis='y')
plt.legend(prop={'size': 13})
plt.show()
# Out:
# [0 1 2 3 4]
# [0.2, 1.2, 2.2, 3.2, 4.2]
# [0.4, 1.4, 2.4000000000000004, 3.4000000000000004, 4.4]

# %% [markdown]
# # 2 bars

# %%
#Accuracies

# set height of bar
IT = [1, 0.5]
#IT = [12, 30, 1, 8, 22]
#ECE = [28, 6, 16, 5, 10]
#CSE = [29, 3, 24, 25, 17]

barWidth = 0.02
fig = plt.subplots(figsize =(12, 8))
 
# set height of bar
p_000 = [80.66, 80.27]
p_025 = [80.04, 79.71]
p_050 = [80.25, 79.93]
p_075 = [79.20, 78.56]
 
# Set position of bar on X axis
#br1 = np.arange(len(IT))
br1 = [0,0.15]
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]
print(br1)
print(br2)
print(br3)
print(br4)
# Make the plot
plt.bar(br1, p_000, color ='#599ad3', width = barWidth,
        edgecolor ='grey', label ='\u03B1 = 0,00')
plt.bar(br2, p_025, color ='#f9a65a', width = barWidth,
        edgecolor ='grey', label ='\u03B1 = 0,25')
plt.bar(br3, p_050, color ='#9e66ab', width = barWidth,
        edgecolor ='grey', label ='\u03B1 = 0,50')
plt.bar(br4, p_075, color ='#cd7058', width = barWidth,
        edgecolor ='grey', label ='\u03B1 = 0,75')
 
# Adding Xticks
plt.xlabel('número de bits',fontsize = 18)
plt.ylabel('Accuracia (%)',fontsize = 18)
#plt.xticks([r + barWidth*1.5 for r in range(len(IT))],['32 bits', '8 bits'], fontsize=14)
#plt.xticks([0.15,0.65],['32 bits', '8 bits'], fontsize=14)
#plt.xticks([0.075,0.575],['32 bits', '8 bits'], fontsize=14)

#plt.title("Accuracies",fontweight ='bold', fontsize = 15)

y = np.random.randint(low=0, high=105, size=100)
plt.yticks(np.arange(0, max(y), 5),fontsize=14)

plt.grid(axis='y')
plt.legend(prop={'size': 12}, loc='lower center')
plt.savefig('cifar_acc_fig.eps', format='eps', dpi=300)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# [0, 0.15]
# [0.02, 0.16999999999999998]
# [0.04, 0.18999999999999997]
# [0.06, 0.20999999999999996]

# %%
#Tamanhos

# set height of bar
IT = [1, 0.5]
#IT = [12, 30, 1, 8, 22]
#ECE = [28, 6, 16, 5, 10]
#CSE = [29, 3, 24, 25, 17]

barWidth = 0.1
fig = plt.subplots(figsize =(12, 8))
 
# set height of bar
p_000 = [35.02, 8.76]
p_025 = [14.70, 3.59]
p_050 = [9.09, 2.64]
p_075 = [6.30, 2.09]
 
# Set position of bar on X axis
#br1 = np.arange(len(IT))
br1 = [0,0.5]
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]
print(br1)
print(br2)
print(br3)
print(br4)
# Make the plot
plt.bar(br1, p_000, color ='#599ad3', width = barWidth,
        edgecolor ='grey', label ='\u03B1 = 0,00')
plt.bar(br2, p_025, color ='#f9a65a', width = barWidth,
        edgecolor ='grey', label ='\u03B1 = 0,25')
plt.bar(br3, p_050, color ='#9e66ab', width = barWidth,
        edgecolor ='grey', label ='\u03B1 = 0,50')
plt.bar(br4, p_075, color ='#cd7058', width = barWidth,
        edgecolor ='grey', label ='\u03B1 = 0,75')
 
# Adding Xticks
plt.xlabel('número de bits',fontsize = 18)
plt.ylabel('Tamanho (Mbits)',fontsize = 18)
#plt.xticks([r + barWidth*1.5 for r in range(len(IT))],['32 bits', '8 bits'], fontsize=14)
plt.xticks([0.15,0.65],['32 bits', '8 bits'], fontsize=14)

#plt.title("Accuracies",fontweight ='bold', fontsize = 15)

y = np.random.randint(low=0, high=45, size=100)
plt.yticks(np.arange(0, max(y), 5),fontsize=14)

plt.grid(axis='y')
plt.legend(prop={'size': 12}, loc='upper right')
plt.savefig('cifar_mb_size_fig.eps', format='eps', dpi=300)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# [0, 0.5]
# [0.1, 0.6]
# [0.2, 0.7]
# [0.30000000000000004, 0.7999999999999999]

# %%
#Sparsity

# set height of bar
IT = [1, 0.5]
#IT = [12, 30, 1, 8, 22]
#ECE = [28, 6, 16, 5, 10]
#CSE = [29, 3, 24, 25, 17]

barWidth = 0.05
fig = plt.subplots(figsize =(12, 8))
 
# set height of bar
#p_000 = [35.02, 8.76]
p_025 = [14.70, 3.59]
p_050 = [9.09, 2.64]
p_075 = [6.30, 2.09]
 
# Set position of bar on X axis
#br1 = np.arange(len(IT))
br1 = [0,0.5]
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]
print(br1)
print(br2)
print(br3)
print(br4)
# Make the plot
plt.bar(br1, p_000, color ='#599ad3', width = barWidth, edgecolor ='grey', label ='\u03B1 = 0,00')
plt.bar(br2, p_025, color ='#f9a65a', width = barWidth,
        edgecolor ='grey', label ='\u03B1 = 0,25')
plt.bar(br3, p_050, color ='#9e66ab', width = barWidth,
        edgecolor ='grey', label ='\u03B1 = 0,50')
#plt.bar(br4, p_075, color ='#cd7058', width = barWidth,edgecolor ='grey', label ='\u03B1 = 0,75')
 
# Adding Xticks
plt.xlabel('número de bits',fontsize = 18)
plt.ylabel('Esparsidade (%)',fontsize = 18)
#plt.xticks([r + barWidth*1.5 for r in range(len(IT))],['32 bits', '8 bits'], fontsize=14)
plt.xticks([0.1,0.6],['32 bits', '8 bits'], fontsize=14)

#plt.title("Accuracies",fontweight ='bold', fontsize = 15)

y = np.random.randint(low=0, high=45, size=100)
plt.yticks(np.arange(0, max(y), 5),fontsize=14)

plt.grid(axis='y')
plt.legend(prop={'size': 12}, loc='upper right')
plt.savefig('cifar_sparsity_fig.eps', format='eps', dpi=300)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# [0, 0.5]
# [0.1, 0.6]
# [0.2, 0.7]
# [0.30000000000000004, 0.7999999999999999]

# %%
#Tamanhos

# set height of bar
IT = [1, 0.5]
#IT = [12, 30, 1, 8, 22]
#ECE = [28, 6, 16, 5, 10]
#CSE = [29, 3, 24, 25, 17]

barWidth = 0.1
fig = plt.subplots(figsize =(12, 8))
 
# set height of bar
p_000 = [7.07, 3.69]
p_025 = [5.52, 2.22]
p_050 = [5.10, 1.92]
p_075 = [4.88, 1.75]
 
# Set position of bar on X axis
#br1 = np.arange(len(IT))
br1 = [0,0.5]
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]
print(br1)
print(br2)
print(br3)
print(br4)
# Make the plot
plt.bar(br1, p_000, color ='#599ad3', width = barWidth,
        edgecolor ='grey', label ='\u03B1 = 0,00')
plt.bar(br2, p_025, color ='#f9a65a', width = barWidth,
        edgecolor ='grey', label ='\u03B1 = 0,25')
plt.bar(br3, p_050, color ='#9e66ab', width = barWidth,
        edgecolor ='grey', label ='\u03B1 = 0,50')
plt.bar(br4, p_075, color ='#cd7058', width = barWidth,
        edgecolor ='grey', label ='\u03B1 = 0,75')
 
# Adding Xticks
plt.xlabel('número de bits',fontsize = 18)
plt.ylabel('Tamanho (Mbytes)',fontsize = 18)
#plt.xticks([r + barWidth*1.5 for r in range(len(IT))],['32 bits', '8 bits'], fontsize=14)
plt.xticks([0.15,0.65],['32 bits', '8 bits'], fontsize=14)

#plt.title("Accuracies",fontweight ='bold', fontsize = 15)

y = np.random.randint(low=0, high=15, size=100)
plt.yticks(np.arange(0, max(y), 1),fontsize=14)

plt.grid(axis='y')
plt.legend(prop={'size': 12}, loc='upper right')
plt.savefig('cifar_mbytes_size_fig.eps', format='eps', dpi=300)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# [0, 0.5]
# [0.1, 0.6]
# [0.2, 0.7]
# [0.30000000000000004, 0.7999999999999999]
